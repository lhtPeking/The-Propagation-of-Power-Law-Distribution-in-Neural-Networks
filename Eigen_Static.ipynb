# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utils import ConnectomeAnalysis, PlotMethod

# %%
## -- Read CSV -- ##
df_Retina = pd.read_csv('./Connectome_Data/Mouse_retina.csv', header=None)
# print(df_Retina.head())
print("Mouse Retina csv Shape: ", df_Retina.shape)

df_Celegans = pd.read_csv('./Connectome_Data/Celegans.csv', header=None)
# print(df_Celegans.head())
print("Celegans csv Shape: ", df_Celegans.shape)

df_Drosophila_central_brain = pd.read_csv('./Connectome_Data/Drosophila_central_brain.csv', header=None)
# print(df_Drosophila_central_brain.head())
print("Drosophila_central_brain csv Shape: ", df_Drosophila_central_brain.shape)

df_Drosophila_optic_medulla = pd.read_csv('./Connectome_Data/Drosophila_optic_medulla.csv', header=None)
# print(df_Drosophila_optic_medulla.head())
print("Drosophila_optic_medulla csv Shape: ", df_Drosophila_optic_medulla.shape)

df_Platynereis_sensory_motor = pd.read_csv('./Connectome_Data/Platynereis_sensory_motor.csv', header=None)
# print(df_Platynereis_sensory_motor.head())
print("Platynereis_sensory_motor csv Shape: ", df_Platynereis_sensory_motor.shape)
# Out:
# Mouse Retina csv Shape:  (525168, 3)
# Celegans csv Shape:  (6817, 3)
# Drosophila_central_brain csv Shape:  (14329229, 3)
# Drosophila_optic_medulla csv Shape:  (33508, 3)
# Platynereis_sensory_motor csv Shape:  (1090, 3)

# %% [markdown]
# # Connectome topology conserved

# %% [markdown]
# ## Indegree analysis

# %% [markdown]
# ## drosophila_optic_medull

# %%
## -- construct connection matrix -- ##
connection_matrix_drosophila_optic_medulla = ConnectomeAnalysis.construct_connection_matrix('./Connectome_Data/Drosophila_optic_medulla.csv', make_dense=True)
print("drosophila_optic_medull connection matrix shape:", connection_matrix_drosophila_optic_medulla.shape)

## -- compute eigenspectrum -- ##
eigenvalue_list_drosophila_optic_medulla = ConnectomeAnalysis.compute_eigenspectrum(connection_matrix_drosophila_optic_medulla, symmetrization=True)

## -- compute shuffled eigenspectrum -- ##
eigenvalue_list_shuffled_drosophila_optic_medulla = ConnectomeAnalysis.compute_shuffled_eigenspectrum(connection_matrix_drosophila_optic_medulla, symmetrization=True, shuffle_diagonal=True, seed=42)

## -- compute brunel weighted eigenspectrum -- ##
brunel_weighted_eigenvalue_list_drosophila_optic_medulla = ConnectomeAnalysis.compute_brunel_weight_eigenspectrum(connection_matrix_drosophila_optic_medulla, symmetrization=True, neg_fraction=1/5, scale=4.0, seed=42)
# Out:
# drosophila_optic_medull connection matrix shape: (1781, 1781)

# %%
## -- plot and regession -- ##
_ = PlotMethod.log_log_plot(
        connection_matrix_drosophila_optic_medulla, # list or matrix 
        bin_num=200, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.1,
        higherbound=0.9,
        num_points=500, # interception point number
        density=True,
        color_scatter="black",
        color_fit="grey",
        show=True,
        ax=None,
        return_params=True,
        xlabel="Log(Connection_Strength)"
        )
# Out:
# Fitted line: slope = -1.60

# %%
## -- plot and regession -- ##
slope1, intercept1, ax_1 = PlotMethod.log_log_plot(
        eigenvalue_list_drosophila_optic_medulla, # list or matrix 
        bin_num=1000, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.1,
        higherbound=0.9,
        num_points=1000, # interception point number
        density=True,
        color_scatter="darkblue",
        color_fit="lightblue",
        show=False,
        ax=None,
        return_params=True,
        xlabel="Log(Eigenvalue)"
        )

_ = PlotMethod.log_log_plot(
        eigenvalue_list_shuffled_drosophila_optic_medulla, # list or matrix 
        bin_num=1000, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.1,
        higherbound=0.9,
        num_points=1000, # interception point number
        density=True,
        color_scatter="green",
        color_fit="green",
        show=False,
        ax=ax_1,
        return_params=True,
        xlabel="Log(Eigenvalue)"
        )



_ = PlotMethod.log_log_plot(
        brunel_weighted_eigenvalue_list_drosophila_optic_medulla, # list or matrix 
        bin_num=1000, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.1,
        higherbound=0.9,
        num_points=1000, # interception point number
        density=True,
        color_scatter="red",
        color_fit="salmon",
        show=True,
        ax=ax_1,
        return_params=True,
        xlabel="Log(Eigenvalue)"
        )
# Out:
# Fitted line: slope = -1.26
# Fitted line: slope = -1.00
# Fitted line: slope = -1.18

# %% [markdown]
# ## Mouse Retina

# %%
## -- construct connection matrix -- ##
connection_matrix_mouse_retina = ConnectomeAnalysis.construct_connection_matrix('./Connectome_Data/Mouse_retina.csv', make_dense=True)
print("mouse_retina connection matrix shape:", connection_matrix_mouse_retina.shape)

## -- compute eigenspectrum -- ##
eigenvalue_list_mouse_retina = ConnectomeAnalysis.compute_eigenspectrum(connection_matrix_mouse_retina, symmetrization=True)

## -- compute shuffled eigenspectrum -- ##
eigenvalue_list_shuffled_mouse_retina = ConnectomeAnalysis.compute_shuffled_eigenspectrum(connection_matrix_mouse_retina, symmetrization=True, shuffle_diagonal=True, seed=42)

## -- compute brunel weighted eigenspectrum -- ##
brunel_weighted_eigenvalue_list_mouse_retina = ConnectomeAnalysis.compute_brunel_weight_eigenspectrum(connection_matrix_mouse_retina, symmetrization=True, neg_fraction=1/5, scale=4.0, seed=42)
# Out:
# mouse_retina connection matrix shape: (1076, 1076)

# %%
## -- plot and regession -- ##
_ = PlotMethod.log_log_plot(
        connection_matrix_mouse_retina, # list or matrix 
        bin_num=1000, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.1,
        higherbound=0.9,
        num_points=500, # interception point number
        density=True,
        color_scatter="black",
        color_fit="grey",
        show=True,
        ax=None,
        return_params=True,
        xlabel="Log(Connection_Strength)"
        )
# Out:
# Fitted line: slope = -2.40

# %%
## -- plot and regession -- ##
slope2, intercept2, ax_2 = PlotMethod.log_log_plot(
        eigenvalue_list_mouse_retina, # list or matrix 
        bin_num=100, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.1,
        higherbound=0.9,
        num_points=1000, # interception point number
        density=True,
        color_scatter="darkblue",
        color_fit="lightblue",
        show=False,
        ax=None,
        return_params=True,
        xlabel="Log(Eigenvalue)"
        )

_ = PlotMethod.log_log_plot(
        eigenvalue_list_shuffled_mouse_retina, # list or matrix 
        bin_num=100, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.1,
        higherbound=0.9,
        num_points=1000, # interception point number
        density=True,
        color_scatter="green",
        color_fit="green",
        show=False,
        ax=ax_2,
        return_params=True,
        xlabel="Log(Eigenvalue)"
        )

_ = PlotMethod.log_log_plot(
        brunel_weighted_eigenvalue_list_mouse_retina, # list or matrix 
        bin_num=100, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.1,
        higherbound=0.9,
        num_points=1000, # interception point number
        density=True,
        color_scatter="red",
        color_fit="salmon",
        show=True,
        ax=ax_2,
        return_params=True,
        xlabel="Log(Eigenvalue)"
        )
# Out:
# Fitted line: slope = -1.46
# Fitted line: slope = -1.39
# Fitted line: slope = -1.30

# %% [markdown]
# ## Drosophila_central_brain

# %%
## -- construct connection matrix -- ##
connection_matrix_Drosophila_central_brain = ConnectomeAnalysis.construct_connection_matrix('./Connectome_Data/Drosophila_central_brain.csv', make_dense=True)
print("Drosophila_central_brain connection matrix shape:", connection_matrix_Drosophila_central_brain.shape)

## -- compute eigenspectrum -- ##
eigenvalue_list_Drosophila_central_brain = ConnectomeAnalysis.compute_eigenspectrum(connection_matrix_Drosophila_central_brain, symmetrization=True)

## -- compute brunel weighted eigenspectrum -- ##
brunel_weighted_eigenvalue_list_Drosophila_central_brain = ConnectomeAnalysis.compute_brunel_weight_eigenspectrum(connection_matrix_Drosophila_central_brain, symmetrization=True, neg_fraction=1/5, scale=4.0, seed=42)
# Out:
# Drosophila_central_brain connection matrix shape: (21739, 21739)

# %%
## -- plot and regession -- ##
_ = PlotMethod.log_log_plot(
        connection_matrix_Drosophila_central_brain, # list or matrix 
        bin_num=1000, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.1,
        higherbound=0.90,
        num_points=1000, # interception point number
        density=True,
        color_scatter="black",
        color_fit="grey",
        show=True,
        ax=None,
        return_params=True,
        xlabel="Log(Connection_Strength)"
        )

# %%
## -- plot and regession -- ##
slope3, intercept3, ax_3 = PlotMethod.log_log_plot(
        eigenvalue_list_Drosophila_central_brain, # list or matrix 
        bin_num=1000, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.1,
        higherbound=0.9,
        num_points=1000, # interception point number
        density=True,
        color_scatter="darkblue",
        color_fit="lightblue",
        show=False,
        ax=None,
        return_params=True,
        xlabel="Log(Eigenvalue)"
        )

_ = PlotMethod.log_log_plot(
        brunel_weighted_eigenvalue_list_Drosophila_central_brain, # list or matrix 
        bin_num=1000, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.1,
        higherbound=0.9,
        num_points=1000, # interception point number
        density=True,
        color_scatter="red",
        color_fit="salmon",
        show=True,
        ax=ax_3,
        return_params=True,
        xlabel="Log(Eigenvalue)"
        )

# %% [markdown]
# # Connectome topology abolished

# %% [markdown]
# ## Random matrix

# %%
rng = np.random.default_rng(42)
mu = 1.5
RM = rng.pareto(mu, size=(10000, 10000)) + 1

## -- compute eigenspectrum -- ##
eigenvalue_list_RM = ConnectomeAnalysis.compute_shuffled_eigenspectrum(RM, symmetrization=True, shuffle_diagonal=True, seed=42)

## -- compute shuffled brunel weighted eigenspectrum -- ##
shuffled_brunel_weighted_eigenvalue_list_RM = ConnectomeAnalysis.compute_shuffled_brunel_weight_eigenspectrum(RM, symmetrization=True, shuffle_diagonal=True, neg_fraction=1/5, scale=4.0, seed=42)

# %%
## -- plot and regession -- ##
slope5, intercept5, ax_5 = PlotMethod.log_log_plot(
        eigenvalue_list_RM, # list or matrix 
        bin_num=1000, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.05,
        higherbound=0.8,
        num_points=1000, # interception point number
        density=True,
        color_scatter="darkblue",
        color_fit="lightblue",
        show=False,
        ax=None,
        return_params=True,
        xlabel="Log(Eigenvalue)"
        )

slope6, intercept6, ax_6 = PlotMethod.log_log_plot(
        shuffled_brunel_weighted_eigenvalue_list_RM, # list or matrix 
        bin_num=1000, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.05,
        higherbound=0.8,
        num_points=1000, # interception point number
        density=True,
        color_scatter="red",
        color_fit="salmon",
        show=True,
        ax=ax_5,
        return_params=True,
        xlabel="Log(Eigenvalue)"
        )

print(intercept5, intercept6, intercept6-intercept5)
# Out:
# Fitted line: slope = -2.45
# Fitted line: slope = -2.22
# 9.166335435225863 8.194534487408472 -0.9718009478173908

# %% [markdown]
# ## Shuffled connectome matrix

# %%
## -- construct connection matrix -- ##
connection_matrix_mouse_retina = ConnectomeAnalysis.construct_connection_matrix('./Connectome_Data/Mouse_retina.csv', make_dense=True)
print("mouse_retina connection matrix shape:", connection_matrix_mouse_retina.shape)

## -- compute shuffled eigenspectrum -- ##
eigenvalue_list_shuffled_mouse_retina = ConnectomeAnalysis.compute_shuffled_eigenspectrum(connection_matrix_mouse_retina, symmetrization=True, shuffle_diagonal=True, seed=42)

## -- compute shuffled brunel weighted eigenspectrum -- ##
shuffled_brunel_weighted_eigenvalue_list_mouse_retina = ConnectomeAnalysis.compute_shuffled_brunel_weight_eigenspectrum(connection_matrix_mouse_retina, symmetrization=True, shuffle_diagonal=True, neg_fraction=1/5, scale=4.0, seed=42)

# %%
## -- plot and regession -- ##
slope4, intercept4, ax_4 = PlotMethod.log_log_plot(
        eigenvalue_list_shuffled_mouse_retina, # list or matrix 
        bin_num=120, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.4,
        higherbound=0.9,
        num_points=1000, # interception point number
        density=True,
        color_scatter="darkblue",
        color_fit="lightblue",
        show=False,
        ax=None,
        return_params=True,
        xlabel="Log(Eigenvalue)"
        )

_ = PlotMethod.log_log_plot(
        shuffled_brunel_weighted_eigenvalue_list_mouse_retina, # list or matrix 
        bin_num=120, 
        regression=True,
        range_=None, # tuple: (min,max)
        lowerbound=0.4,
        higherbound=0.9,
        num_points=1000, # interception point number
        density=True,
        color_scatter="red",
        color_fit="salmon",
        show=True,
        ax=ax_4,
        return_params=True,
        xlabel="Log(Eigenvalue)"
        )
